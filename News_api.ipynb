# %%
import time
import csv
import os
import json

# Preinstalled packages
import requests
import pandas as pd
import os

# Define desired work folder, where you want to save your .csv files
# Windows Example
os.chdir('C:\\Users\\Vasanth Avadhutha\\Downloads\\News')
# Linux Example
# os.chdir('/mnt/c/Users/user_name/PycharmProjects/extract_news_data')

# URL of our News API
base_url = 'https://api.newscatcherapi.com/v2/search'

# Your API key
X_API_KEY = 'MGAFR1se4B4Ve4oTKYxZZue28_-ekzERM2F2-OPv7_Q'

# %%
headers = {'x-api-key': X_API_KEY}

# %%
params = {
    'q': 'Bitcoin AND Ethereum AND Dogecoin',
    'lang': 'en',
    'to_rank': 10000,
    'page_size': 100,
    'page': 1
    }

# Make a simple call with both headers and params
response = requests.get(base_url, headers=headers, params=params)

# Encode received results
results = json.loads(response.text.encode())
if response.status_code == 200:
    print('Done')
else:
    print(results)
    print('ERROR: API call failed.')
# Out:
# Done

# %%
# Import data into pandas
pandas_table = pd.DataFrame(results['articles'])

# %%
# Variable to store all found news articles, mp stands for "multiple queries"
all_news_articles_mp = []

params = [
    {
        'q': 'Politics',
        'lang': 'en',
        'to_rank': 10000,
        'topic': "business",
        'page_size': 100,
        'page': 1
    },
    {
        'q': 'Ethereum',
        'lang': 'en',
        'to_rank': 10000,
        'topic': "business",
        'page_size': 100,
        'page': 1
    },
    {
        'q': 'Dogecoin',
        'lang': 'en',
        'to_rank': 10000,
        'topic': "business",
        'page_size': 100,
        'page': 1
    }
]

# Infinite loop which ends when all articles are extracted
for separated_param in params:

    print(f'Query in use => {str(separated_param)}')
    
    while True:
        # Wait for 1 second between each call
        time.sleep(1)

        # GET Call from previous section enriched with some logs
        response = requests.get(base_url, headers=headers, params=separated_param)
        results = json.loads(response.text.encode())
        if response.status_code == 200:
            print(f'Done for page number => {separated_param["page"]}')


            # Adding your parameters to each result to be able to explore afterwards
            for i in results['articles']:
                i['used_params'] = str(separated_param)


            # Storing all found articles
            all_news_articles_mp.extend(results['articles'])

            # Ensuring to cover all pages by incrementing "page" value at each iteration
            separated_param['page'] += 1
            if separated_param['page'] > results['total_pages']:
                print("All articles have been extracted")
                break
            else:
                print(f'Proceed extracting page number => {separated_param["page"]}')
        else:
            print(results)
            print(f'ERROR: API call failed for page number => {separated_param["page"]}')
            break

print(f'Number of extracted articles => {str(len(all_news_articles_mp))}')
# Out:
# Query in use => {'q': 'Politics', 'lang': 'en', 'to_rank': 10000, 'topic': 'business', 'page_size': 100, 'page': 1}
# Done for page number => 1
# Proceed extracting page number => 2
# Done for page number => 2
# Proceed extracting page number => 3
# Done for page number => 3
# Proceed extracting page number => 4
# Done for page number => 4
# Proceed extracting page number => 5
# Done for page number => 5
# Proceed extracting page number => 6
# Done for page number => 6
# Proceed extracting page number => 7
# Done for page number => 7
# Proceed extracting page number => 8
# Done for page number => 8
# Proceed extracting page number => 9
# Done for page number => 9
# Proceed extracting page number => 10
# Done for page number => 10
# Proceed extracting page number => 11
# Done for page number => 11
# Proceed extracting page number => 12
# Done for page number => 12
# Proceed extracting page number => 13
# Done for page number => 13
# Proceed extracting page number => 14
# Done for page number => 14
# Proceed extracting page number => 15
# {'status': 'error', 'error_code': 'LimitReached', 'message': 'Monthly API calls limit reached: 50'}
# ERROR: API call failed for page number => 15
# Query in use => {'q': 'Ethereum', 'lang': 'en', 'to_rank': 10000, 'topic': 'business', 'page_size': 100, 'page': 1}
# {'status': 'error', 'error_code': 'LimitReached', 'message': 'Monthly API calls limit reached: 50'}
# ERROR: API call failed for page number => 1
# Query in use => {'q': 'Dogecoin', 'lang': 'en', 'to_rank': 10000, 'topic': 'business', 'page_size': 100, 'page': 1}
# {'status': 'error', 'error_code': 'LimitReached', 'message': 'Monthly API calls limit reached: 50'}
# ERROR: API call failed for page number => 1
# Number of extracted articles => 1400

# %%
pandas_table.head()
# Out:
#                                                title             author  \
# 0  Crypto Price Today Live: Bitcoin holds $17k; L...        Pawan Nahar
# 1  A Look At Bitcoin, Ethereum, Dogecoin Heading ...   Melanie Schaffer
# 2  Axie Infinity Token (AXS) Rallies 20% Even As ...      Mehab Qureshi
# 3  Mark Cuban Joins Elon Musk In Defending Dogeco...  Shivdeep Dhaliwal
# 4  Crypto prices today: Bitcoin & Ethereum surge,...     Nidhi Bhardwaj
#
#         published_date published_date_precision  \
# 0  2022-12-07 06:30:00         timezone unknown
# 1  2022-12-02 21:27:15                     full
# 2  2022-12-06 03:10:18                     full
# 3  2022-12-05 14:46:22                     full
# 4  2022-12-07 00:00:00                     date
#
#                                                 link       clean_url  \
# 0  https://economictimes.indiatimes.com/markets/c...  indiatimes.com
# 1  https://www.benzinga.com/markets/cryptocurrenc...    benzinga.com
# 2  https://www.benzinga.com/markets/cryptocurrenc...    benzinga.com
# 3  https://www.benzinga.com/markets/cryptocurrenc...    benzinga.com
# 4  https://www.indiatoday.in/cryptocurrency/story...   indiatoday.in
#
#                                              excerpt  \
# 0  Crypto wallet maker Ledger has partnered with ...
# 1  Bitcoin (CRYPTO: BTC) and Ethereum (CRYPTO: ET...
# 2  AXS (CRYPTO: AXS), the native token behind Axi...
# 3  Dallas Mavericks owner Mark Cuban said on Wedn...
# 4  Cryptocurrencies traded mix on Wednesday, with...
#
#                                              summary          rights  rank  \
# 0  RelatedMost ReadMost SharedCrypto Price Today:...  indiatimes.com   296
# 1  Bitcoin BTC/USD and Ethereum ETH/USD were trad...    benzinga.com  1933
# 2  AXS AXS/USD, the native token behind Axie Infi...    benzinga.com  1933
# 3  Dallas Mavericks owner Mark Cuban said on Wedn...    benzinga.com  1933
# 4  Cryptocurrencies traded mixed today, with the ...   indiatoday.in  1817
#
#        topic country language                            authors  \
# 0  economics      IN       en                        Pawan Nahar
# 1       news      US       en   Benzinga Editor,Melanie Schaffer
# 2       news      US       en                      Mehab Qureshi
# 3       news      US       en  Benzinga Editor,Shivdeep Dhaliwal
# 4       news      IN       en                     Nidhi Bhardwaj
#
#                                                media  is_opinion  \
# 0  https://img.etimg.com/thumb/msid-96047673,widt...       False
# 1  https://cdn.benzinga.com/files/images/story/20...       False
# 2  https://cdn.benzinga.com/files/images/story/20...       False
# 3  https://cdn.benzinga.com/files/images/story/20...       False
# 4  https://akm-img-a-in.tosshub.com/indiatoday/im...       False
#
#   twitter_account     _score                               _id
# 0  @EconomicTimes  31.050785  86d79e6f67914b548ba2f57ee15ffb71
# 1       @benzinga  30.833923  9139bc37ec6ecdfecd9aac9d93c934a5
# 2       @benzinga  29.398054  1f4375d9c85aebcf71f6a00ed7f6e8f8
# 3       @benzinga  28.529750  68ce285cdd38b71aeac9cc0cfae80b92
# 4     @indiatoday  28.117893  dc5ae2975c6913f1f6c638215a50148c

# %%
 #Define variables
unique_ids = []
all_news_articles = []

# Iterate on each article and check whether we saw this _id before
for article in all_news_articles_mp:
    if article['_id'] not in unique_ids:
        unique_ids.append(article['_id'])
        all_news_articles.append(article)

# %%
field_names = list(all_news_articles[0].keys())
# Generate CSV file from dict
with open('extracted_news_articles.csv', 'w', encoding="utf-8", newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=field_names, delimiter=";")
    writer.writeheader()
    writer.writerows(all_news_articles)

# %%
# Generate CSV from Pandas table
# Create Pandas table
pandas_table = pd.DataFrame(all_news_articles)

# Generate CSV df.to_json(orient='records')[1:-1].replace('},{', '} {')
# pandas_table.to_csv('extracted_news_articles2.csv', encoding='utf-8', sep=',')
out = pandas_table.to_json(orient='records')[1:-1].replace('},{', '} {')
with open('file_name.json', 'w') as f:
    f.write(out)
